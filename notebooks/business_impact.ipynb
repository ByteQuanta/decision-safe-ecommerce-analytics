# %% [markdown]
# # Decision-Safe E-commerce Analytics
#
# This notebook demonstrates how business metrics can be safely
# published only when upstream data quality meets explicit
# decision thresholds.
#
# Traditional dashboards always update.
# This system sometimes refuses to.

# %%
import duckdb

con = duckdb.connect("../warehouse/duckdb/analytics.duckdb")
con.execute("select * from analytics_order_summary").fetchdf()
